# %% [markdown]
# <a href="https://colab.research.google.com/github/Agil0509/Deep-Learning/blob/main/Computer_vision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import zipfile
# !wget https://storage.googleapis.com/ztm_tf_course/food_vision/pizza_steak.zip
# Out:
# --2024-09-06 12:13:59--  https://storage.googleapis.com/ztm_tf_course/food_vision/pizza_steak.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.200.207, 74.125.130.207, 74.125.68.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.200.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 109540975 (104M) [application/zip]
# Saving to: ‘pizza_steak.zip’
#
# pizza_steak.zip     100%[===================>] 104.47M  22.6MB/s    in 5.8s
#
# 2024-09-06 12:14:06 (18.1 MB/s) - ‘pizza_steak.zip’ saved [109540975/109540975]

# %%
zip_ref=zipfile.ZipFile("/content/pizza_steak.zip")
zip_ref.extractall()
zip_ref.close()

# %%
# !ls pizza_steak
# Out:
# test  train

# %%
# !ls pizza_steak/train
# Out:
# pizza  steak

# %%
import os

for dirpath, dirnames, filenames in os.walk("pizza_steak"):
  print(f"There are {len(dirnames)} directories and {len(filenames)} images in {dirpath}.")
# Out:
# There are 2 directories and 0 images in pizza_steak.
# There are 2 directories and 0 images in pizza_steak/test.
# There are 0 directories and 250 images in pizza_steak/test/pizza.
# There are 0 directories and 250 images in pizza_steak/test/steak.
# There are 2 directories and 0 images in pizza_steak/train.
# There are 0 directories and 750 images in pizza_steak/train/pizza.
# There are 0 directories and 750 images in pizza_steak/train/steak.

# %%
num_steak_images_train=len(os.listdir("pizza_steak/train/steak"))
num_steak_images_train
# Out:
# 750

# %%
import pathlib
import numpy as np

data_dir=pathlib.Path("pizza_steak/train")
data_dir
# Out:
# PosixPath('pizza_steak/train')

# %%
class_names=np.array(sorted([item.name for item in data_dir.glob('*')]))
print(class_names)
# Out:
# ['pizza' 'steak']

# %%
for item in data_dir.glob('*'):
  print(item,' ',item.name)
# Out:
# pizza_steak/train/pizza   pizza
# pizza_steak/train/steak   steak

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import random

def view_random_image(target_dir,target_class):
  target_folder=target_dir+target_class
  random_image=random.sample(os.listdir(target_folder),1)
  img=mpimg.imread(target_folder+'/'+random_image[0])
  plt.imshow(img)
  plt.title(target_class)
  plt.axis('off')

  print(f'Image shape: {img.shape}')
  return img

# %%
img=view_random_image(target_dir='pizza_steak/train/',target_class='steak')
# Out:
# Image shape: (512, 512, 3)

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

tf.random.set_seed(42)

train_datagen=ImageDataGenerator(rescale=1./255)
valid_datagen=ImageDataGenerator(rescale=1./255)

train_dir='/content/pizza_steak/train'
test_dir='/content/pizza_steak/test'

train_data=train_datagen.flow_from_directory(train_dir,
                                             batch_size=32,
                                             target_size=(224,224),
                                             class_mode='binary',
                                             seed=42)

valid_data=valid_datagen.flow_from_directory(test_dir,
                                             batch_size=32,
                                             target_size=(224,224),
                                             class_mode='binary',
                                             seed=42)
# Out:
# Found 1500 images belonging to 2 classes.
# Found 500 images belonging to 2 classes.

# %%
model_1=tf.keras.Sequential([
    tf.keras.layers.Input(shape=(224,224,3)),
    tf.keras.layers.Conv2D(filters=10,
                           kernel_size=3,
                           activation='relu',
                           strides=1,
                           padding='same',
                           kernel_initializer='he_normal'),
    tf.keras.layers.Conv2D(10,3,activation='relu',kernel_initializer='he_normal'),
    tf.keras.layers.MaxPool2D(pool_size=2,padding='valid'),
    tf.keras.layers.Conv2D(10,3,activation='relu',kernel_initializer='he_normal'),
    tf.keras.layers.Conv2D(10,3,activation='relu',kernel_initializer='he_normal'),
    tf.keras.layers.MaxPool2D(2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(1,activation='linear')
])

model_1.compile(
    loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
    optimizer=tf.keras.optimizers.Adam(),
    metrics=['accuracy']
)

history=model_1.fit(train_data,
                    epochs=5,
                    validation_data=valid_data)
# Out:
# Epoch 1/5
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 19s 234ms/step - accuracy: 0.5209 - loss: 1.4660 - val_accuracy: 0.6080 - val_loss: 0.5653
# Epoch 2/5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 10s 132ms/step - accuracy: 0.6997 - loss: 0.5296 - val_accuracy: 0.8240 - val_loss: 0.4071
# Epoch 3/5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 109ms/step - accuracy: 0.8183 - loss: 0.4074 - val_accuracy: 0.8220 - val_loss: 0.3610
# Epoch 4/5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 10s 107ms/step - accuracy: 0.8612 - loss: 0.3245 - val_accuracy: 0.8360 - val_loss: 0.4161
# Epoch 5/5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 7s 141ms/step - accuracy: 0.9051 - loss: 0.2508 - val_accuracy: 0.8580 - val_loss: 0.3461

# %%
model_1.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 224, 224, 10)        │             280 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 222, 222, 10)        │             910 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 111, 111, 10)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 109, 109, 10)        │             910 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 107, 107, 10)        │             910 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 53, 53, 10)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 28090)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │          28,091 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 93,305 (364.48 KB)
#  Trainable params: 31,101 (121.49 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 62,204 (242.99 KB)

# %%
tf.random.set_seed(42)

model_2=tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(224,224,3)),
    tf.keras.layers.Dense(4,activation='relu'),
    tf.keras.layers.Dense(4,activation='relu'),
    tf.keras.layers.Dense(1,activation='sigmoid')
])

model_2.compile(
    loss='binary_crossentropy',
    optimizer=tf.keras.optimizers.Adam(),
    metrics=['accuracy']
)

model_2.fit(train_data,
                    epochs=5,
                    validation_data=valid_data)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 9s 132ms/step - accuracy: 0.4928 - loss: 2.7063 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 2/5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 7s 100ms/step - accuracy: 0.4960 - loss: 0.6933 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 3/5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 10s 96ms/step - accuracy: 0.5009 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 4/5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 11s 112ms/step - accuracy: 0.4900 - loss: 0.6935 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 5/5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.4955 - loss: 0.6933 - val_accuracy: 0.5000 - val_loss: 0.6932

# %%
model_2.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten_1 (Flatten)                  │ (None, 150528)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 4)                   │         602,116 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 4)                   │              20 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │               5 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,806,425 (6.89 MB)
#  Trainable params: 602,141 (2.30 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 1,204,284 (4.59 MB)

# %%
model_3=tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(224,224,3)),
    tf.keras.layers.Dense(100,activation='relu'),
    tf.keras.layers.Dense(100,activation='relu'),
    tf.keras.layers.Dense(100,activation='relu'),
    tf.keras.layers.Dense(1,activation='sigmoid')
])

model_3.compile(
    loss=tf.keras.losses.BinaryCrossentropy(),
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.00001),
    metrics=['accuracy']
)

model_3.fit(train_data,
            epochs=5,
            validation_data=valid_data)
# Out:
# Epoch 1/5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 10s 160ms/step - accuracy: 0.5907 - loss: 0.6532 - val_accuracy: 0.7500 - val_loss: 0.4998
# Epoch 2/5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 101ms/step - accuracy: 0.7679 - loss: 0.4956 - val_accuracy: 0.7920 - val_loss: 0.4617
# Epoch 3/5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 10s 97ms/step - accuracy: 0.7968 - loss: 0.4573 - val_accuracy: 0.7540 - val_loss: 0.5004
# Epoch 4/5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 120ms/step - accuracy: 0.7975 - loss: 0.4398 - val_accuracy: 0.7780 - val_loss: 0.4630
# Epoch 5/5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 10s 125ms/step - accuracy: 0.7941 - loss: 0.4701 - val_accuracy: 0.7880 - val_loss: 0.4484

# %%
model_3.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten_2 (Flatten)                  │ (None, 150528)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 100)                 │      15,052,900 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 100)                 │          10,100 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 100)                 │          10,100 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 1)                   │             101 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 45,219,605 (172.50 MB)
#  Trainable params: 15,073,201 (57.50 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 30,146,404 (115.00 MB)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen=ImageDataGenerator(rescale=1/255.)
test_datagen=ImageDataGenerator(rescale=1/255.)

train_data=train_datagen.flow_from_directory(directory=train_dir,
                                             target_size=(224,224),
                                             class_mode='binary',
                                             batch_size=32)
test_data=test_datagen.flow_from_directory(directory=test_dir,
                                             target_size=(224,224),
                                             class_mode='binary',
                                             batch_size=32)
# Out:
# Found 1500 images belonging to 2 classes.
# Found 500 images belonging to 2 classes.

# %%
images,labels=next(train_data)

# %%
len(images),len(labels)
# Out:
# (32, 32)

# %%
labels[0]
# Out:
# 0.0

# %%
from tensorflow.keras.optimizers import Adam,AdamW
from tensorflow.keras.layers import Dense,Flatten,Conv2D,MaxPool2D,Activation
from tensorflow.keras import Sequential

# %%
tf.random.set_seed(42)
model_4=Sequential([
    tf.keras.layers.Input(shape=(224,224,3)),
    Conv2D(filters=100,
           kernel_size=3,
           strides=1,
           padding='valid',
           activation='relu'),
    Conv2D(100,3,activation='relu'),
    MaxPool2D(pool_size=2),
    Conv2D(100,3,activation='relu'),
    Flatten(),
    Dense(1,activation='sigmoid')
])

# %%
model_4.compile(loss=tf.keras.losses.BinaryCrossentropy(),
                optimizer=Adam(),
                metrics=['accuracy']
)

# %%
model_4.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_20 (Conv2D)                   │ (None, 222, 222, 100)       │           2,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_21 (Conv2D)                   │ (None, 220, 220, 100)       │          90,100 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 110, 110, 100)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_22 (Conv2D)                   │ (None, 108, 108, 100)       │          90,100 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_6 (Flatten)                  │ (None, 1166400)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_11 (Dense)                     │ (None, 1)                   │       1,166,401 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,349,401 (5.15 MB)
#  Trainable params: 1,349,401 (5.15 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
len(train_data),len(test_data)
# Out:
# (47, 16)

# %%
history_4=model_4.fit(train_data,
                      epochs=5,
                      validation_data=test_data)
# Out:
# Epoch 1/5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 20s 373ms/step - accuracy: 0.6171 - loss: 0.9884 - val_accuracy: 0.8120 - val_loss: 0.4431
# Epoch 2/5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 16s 333ms/step - accuracy: 0.7622 - loss: 0.5088 - val_accuracy: 0.8420 - val_loss: 0.3598
# Epoch 3/5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 20s 331ms/step - accuracy: 0.8304 - loss: 0.4091 - val_accuracy: 0.8400 - val_loss: 0.3807
# Epoch 4/5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 21s 326ms/step - accuracy: 0.8644 - loss: 0.3620 - val_accuracy: 0.8740 - val_loss: 0.3488
# Epoch 5/5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 16s 330ms/step - accuracy: 0.8866 - loss: 0.2858 - val_accuracy: 0.8060 - val_loss: 0.4199

# %%
model_4.evaluate(test_data)
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - accuracy: 0.8144 - loss: 0.4214
# [0.41987693309783936, 0.8059999942779541]

# %%
history_4.history
# Out:
# {'accuracy': [0.6800000071525574,
#   0.7746666669845581,
#   0.8159999847412109,
#   0.8613333106040955,
#   0.8846666812896729],
#  'loss': [0.7178224921226501,
#   0.47428274154663086,
#   0.4188235402107239,
#   0.35712751746177673,
#   0.2848362922668457],
#  'val_accuracy': [0.8119999766349792,
#   0.8420000076293945,
#   0.8399999737739563,
#   0.8740000128746033,
#   0.8059999942779541],
#  'val_loss': [0.443051278591156,
#   0.3598361015319824,
#   0.38065946102142334,
#   0.3487914502620697,
#   0.41987696290016174]}

# %%
import pandas as pd
pd.DataFrame(history_4.history).plot(figsize=(10,7));

# %%
def plot_loss_curves(history):
  loss=history.history['loss']
  val_loss=history.history['val_loss']
  accuracy=history.history['accuracy']
  val_accuracy=history.history['val_accuracy']
  epochs=range(len(history.history['loss']))

  plt.plot(epochs,loss,label='training_loss')
  plt.plot(epochs,val_loss,label='val_loss')
  plt.title('Loss')
  plt.xlabel('Epochs')
  plt.legend()

  plt.figure()
  plt.plot(epochs,accuracy,label='training_accuracy')
  plt.plot(epochs,val_accuracy,label='val_accuracy')
  plt.title('Accuracy')
  plt.xlabel('Epochs')
  plt.legend()

# %%
plot_loss_curves(history_4)

# %%
from tensorflow import keras

tf.random.set_seed(42)
model_4=Sequential([
    tf.keras.layers.Input(shape=(224,224,3)),
    Conv2D(filters=100,
           kernel_size=4,
           strides=5,
           padding='valid',
           activation='relu'),
    Conv2D(100,3,activation='relu'),
    tf.keras.layers.Dropout(0.2),
    MaxPool2D(pool_size=2),
    Conv2D(100,3,activation='relu'),
    tf.keras.layers.Dropout(0.2),
    Flatten(),
    Dense(1,activation='sigmoid')
])

# %%
model_4.compile(loss=tf.keras.losses.BinaryCrossentropy(),
                optimizer=AdamW(learning_rate=0.0008),
                metrics=['accuracy']
)

# %%
history_4=model_4.fit(train_data,
                      epochs=5,
                      validation_data=test_data)
# Out:
# Epoch 1/5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 14s 209ms/step - accuracy: 0.5382 - loss: 0.6921 - val_accuracy: 0.7320 - val_loss: 0.5191
# Epoch 2/5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 5s 98ms/step - accuracy: 0.7583 - loss: 0.5099 - val_accuracy: 0.8400 - val_loss: 0.4360
# Epoch 3/5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 7s 141ms/step - accuracy: 0.7947 - loss: 0.4616 - val_accuracy: 0.7340 - val_loss: 0.4881
# Epoch 4/5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 5s 98ms/step - accuracy: 0.8018 - loss: 0.4245 - val_accuracy: 0.8400 - val_loss: 0.3774
# Epoch 5/5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 6s 117ms/step - accuracy: 0.8215 - loss: 0.4191 - val_accuracy: 0.8420 - val_loss: 0.3624

# %%
plot_loss_curves(history_4)

# %%
#Augamented dataset
train_datagen_augamented=ImageDataGenerator(rescale=1/255.,
                                            rotation_range=0.2,
                                            shear_range=0.2,
                                            zoom_range=0.2,
                                            width_shift_range=0.2,
                                            height_shift_range=0.2,
                                            horizontal_flip=True)

#Normal dataset
train_datagen=ImageDataGenerator(rescale=1/255.)
test_datagen=ImageDataGenerator(rescale=1/255.)

# %%
print("Train data augamented:")
IMG_SIZE=(224,224)
train_data_augamented=train_datagen_augamented.flow_from_directory(directory=train_dir,
                                                                   target_size=IMG_SIZE,
                                                                   class_mode='binary',
                                                                   batch_size=32,
                                                                   shuffle=False)

print("Non-augamented train data:")
train_data=train_datagen.flow_from_directory(directory=train_dir,
                                             target_size=IMG_SIZE,
                                             class_mode='binary',
                                             batch_size=32,
                                             shuffle=False)

print("Non-augamented test data:")
test_data=test_datagen.flow_from_directory(directory=train_dir,
                                           target_size=(224,224),
                                           class_mode='binary',
                                           batch_size=32,
                                           shuffle=False)
# Out:
# Train data augamented:
# Found 1500 images belonging to 2 classes.
# Non-augamented train data:
# Found 1500 images belonging to 2 classes.
# Non-augamented test data:
# Found 1500 images belonging to 2 classes.

# %%
images,labels=next(train_data)

augamented_images,augamented_labels=next(train_data_augamented)

# %%
import random
random_number=random.randint(1,31)
plt.subplot(2,1,1)
plt.imshow(images[random_number])
plt.title('Original Image')
plt.axis(False)
plt.subplot(2,1,2)
plt.imshow(augamented_images[random_number])
plt.title('Augamented Image')
plt.axis(False);

# %%
model_6=tf.keras.Sequential([
    tf.keras.layers.Input(shape=(224,224,3)),
    tf.keras.layers.Conv2D(filters=10,
                           kernel_size=3,
                           activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=2),
    tf.keras.layers.Conv2D(filters=10,
                           kernel_size=3,
                           activation='relu'),
    tf.keras.layers.MaxPool2D(2),
    tf.keras.layers.Conv2D(filters=10,
                           kernel_size=3,
                           activation='relu'),
    tf.keras.layers.MaxPool2D(2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(1,activation='sigmoid')
])

model_6.compile(
    loss=tf.keras.losses.BinaryCrossentropy(),
    optimizer=tf.keras.optimizers.Adam(),
    metrics=['accuracy']
)

history_6=model_6.fit(train_data_augamented,epochs=5,validation_data=test_data)
# Out:
# Epoch 1/5
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 29s 498ms/step - accuracy: 0.6769 - loss: 0.6878 - val_accuracy: 0.5000 - val_loss: 0.6934
# Epoch 2/5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 26s 495ms/step - accuracy: 0.4105 - loss: 0.7083 - val_accuracy: 0.5213 - val_loss: 0.6823
# Epoch 3/5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 28s 533ms/step - accuracy: 0.4856 - loss: 0.6906 - val_accuracy: 0.5360 - val_loss: 0.6594
# Epoch 4/5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 41s 480ms/step - accuracy: 0.6379 - loss: 0.6635 - val_accuracy: 0.5627 - val_loss: 0.6588
# Epoch 5/5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 25s 448ms/step - accuracy: 0.5457 - loss: 0.6750 - val_accuracy: 0.7720 - val_loss: 0.5643

# %%
print('Augamented and Shuffled train data')
train_data_augamented_and_shuffled = train_datagen_augamented.flow_from_directory(
    directory=train_dir,
    target_size=(224, 224),
    class_mode='binary'
)
# Out:
# Augamented and Shuffled train data
# Found 1500 images belonging to 2 classes.

# %%
model_8=tf.keras.Sequential([
    tf.keras.layers.Input(shape=(224,224,3)),
    tf.keras.layers.Conv2D(32,3,activation='relu',kernel_initializer='he_normal'),
    tf.keras.layers.Conv2D(32,3,activation='relu',kernel_initializer='he_normal'),
    tf.keras.layers.MaxPool2D(pool_size=2),
    tf.keras.layers.Conv2D(32,3,activation='relu',kernel_initializer='he_normal'),
    tf.keras.layers.Conv2D(32,3,activation='relu',kernel_initializer='he_normal'),
    tf.keras.layers.MaxPool2D(2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(1,activation='sigmoid')
])

model_8.compile(
    loss=tf.keras.losses.BinaryCrossentropy(),
    optimizer=tf.keras.optimizers.Adam(),
    metrics=['accuracy']
)

history_8=model_8.fit(train_data_augamented_and_shuffled,epochs=5,validation_data=test_data)
# Out:
# Epoch 1/5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 27s 473ms/step - accuracy: 0.5012 - loss: 1.9813 - val_accuracy: 0.6540 - val_loss: 0.6295
# Epoch 2/5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 27s 520ms/step - accuracy: 0.6449 - loss: 0.6276 - val_accuracy: 0.7427 - val_loss: 0.5012
# Epoch 3/5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 38s 454ms/step - accuracy: 0.7384 - loss: 0.5340 - val_accuracy: 0.7813 - val_loss: 0.4603
# Epoch 4/5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 24s 461ms/step - accuracy: 0.7742 - loss: 0.4773 - val_accuracy: 0.8333 - val_loss: 0.3858
# Epoch 5/5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 23s 445ms/step - accuracy: 0.7735 - loss: 0.4766 - val_accuracy: 0.7807 - val_loss: 0.4985

# %%
plot_loss_curves(history_8)
